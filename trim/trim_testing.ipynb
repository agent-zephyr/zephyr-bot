# %%
import subprocess
# ffmpeg -ss 30 -i input.wmv -c copy -t 10 output.wmv
command = [
    "ffmpeg",
    "-ss", "30",          # Start time at 30 seconds
    "-i", "input.mp4",    # Input file
    "-c", "copy",         # Copy codec
    "-t", "10",           # Duration of 10 seconds
    "output.mp4"          # Output file
]

try:
    subprocess.run(command, check=True)
    command[2] = "40"
    command[8] = "11"
    command[9] = "output2.mp4"
    subprocess.run(command, check=True)
    print("FFmpeg command executed successfully.")
except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955481026/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.27.100
#   Duration: 00:03:10.45, start: 0.000000, bitrate: 2515 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 2383 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'output.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2383 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  274 fps=0.0 q=-1.0 Lsize=    2781kB time=00:00:09.99 bitrate=2278.3kbits/s speed= 945x
# video:2594kB audio:178kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.314000%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955481026/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# FFmpeg command executed successfully.
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.27.100
#   Duration: 00:03:10.45, start: 0.000000, bitrate: 2515 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 2383 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'output2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2383 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  291 fps=0.0 q=-1.0 Lsize=    2742kB time=00:00:10.99 bitrate=2044.0kbits/s speed= 599x
# video:2544kB audio:190kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.335038%

# %%
command = [
    "ffmpeg",
    "-f", "concat",       # Use concat demuxer
    "-safe", "0",         # Allow potentially unsafe file paths
    "-i", "file_list.txt",# Input file list
    "-c:v", "libx264",    # Re-encode during concatenation
    "-crf", "23",
    "-preset", "fast",
    "-c:a", "aac",
    "-b:a", "128k",
    "final.mp4"
]

# Run the command
try:
    subprocess.run(command, check=True)
    print("FFmpeg command executed successfully.")
except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955481026/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fd98d011400] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'file_list.txt':
#   Duration: N/A, start: -0.023220, bitrate: 1730 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], 1602 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x7fd98f832400] using SAR=1/1
# [libx264 @ 0x7fd98f832400] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x7fd98f832400] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x7fd98f832400] 264 - core 161 r3030M 8bd6d28 - H.264/MPEG-4 AVC codec - Copyleft 2003-2020 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=23 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'final.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 23.98 fps, 24k tbn, 23.98 tbc
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       encoder         : Lavc58.91.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       encoder         : Lavc58.91.100 aac
# frame=   23 fps=0.0 q=0.0 size=       0kB time=00:00:01.23 bitrate=   0.3kbits/s dup=1 drop=0 speed=2.45x
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fd98f84d200] Auto-inserting h264_mp4toannexb bitstream filterp=0 speed=0.788x
# frame=  481 fps= 21 q=-1.0 Lsize=    4715kB time=00:00:20.05 bitrate=1926.0kbits/s dup=1 drop=0 speed=0.864x
# video:4385kB audio:314kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.344260%
# [libx264 @ 0x7fd98f832400] frame I:10    Avg QP:14.15  size: 51492
# [libx264 @ 0x7fd98f832400] frame P:152   Avg QP:17.92  size: 14241
# [libx264 @ 0x7fd98f832400] frame B:319   Avg QP:19.96  size:  5673
# [libx264 @ 0x7fd98f832400] consecutive B-frames:  8.5%  6.2%  8.7% 76.5%
# [libx264 @ 0x7fd98f832400] mb I  I16..4: 38.9% 55.3%  5.8%
# [libx264 @ 0x7fd98f832400] mb P  I16..4:  7.5% 14.4%  0.3%  P16..4: 22.3%  4.1%  1.3%  0.0%  0.0%    skip:50.1%
# [libx264 @ 0x7fd98f832400] mb B  I16..4:  1.9%  2.4%  0.0%  B16..8: 17.0%  1.7%  0.1%  direct: 7.8%  skip:69.0%  L0:47.8% L1:48.5% BI: 3.7%
# [libx264 @ 0x7fd98f832400] 8x8 transform intra:61.1% inter:84.2%
# [libx264 @ 0x7fd98f832400] coded y,uvDC,uvAC intra: 22.9% 53.2% 8.1% inter: 3.6% 11.9% 0.1%
# [libx264 @ 0x7fd98f832400] i16 v,h,dc,p: 42% 31% 12% 15%
# [libx264 @ 0x7fd98f832400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 24% 23%  3%  3%  3%  3%  3%  3%
# [libx264 @ 0x7fd98f832400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 27% 14%  4%  7%  6%  5%  4%  3%
# [libx264 @ 0x7fd98f832400] i8c dc,h,v,p: 46% 25% 20%  9%
# [libx264 @ 0x7fd98f832400] Weighted P-Frames: Y:5.9% UV:5.3%
# [libx264 @ 0x7fd98f832400] ref P L0: 74.2% 25.8%
# [libx264 @ 0x7fd98f832400] ref B L0: 86.8% 13.2%
# [libx264 @ 0x7fd98f832400] ref B L1: 96.6%  3.4%
# [libx264 @ 0x7fd98f832400] kb/s:1790.19
# FFmpeg command executed successfully.
# [aac @ 0x7fd98f833c00] Qavg: 158.370

# %%
import json
def timestamp_to_seconds(file_path):

    # Open the file and load its contents
    with open(file_path, 'r') as file:
        data = json.load(file)
        
    print(data)
        
    points = []
        
    for segment in data:
        # Split the timestamp into hours, minutes, and seconds
        hours, minutes, seconds = segment['start_time'].split(':')
        end_hours, end_minutes, end_seconds = segment['end_time'].split(':')
        # Calculate the total number of seconds
        total_start_seconds = int(hours) * 3600 + int(minutes) * 60 + int(seconds)
        total_end_seconds = int(end_hours) * 3600 + int(end_minutes) * 60 + int(end_seconds)
        # start, duration
        points.append((total_start_seconds, total_end_seconds - total_start_seconds))
        
    return points
    
timestamp_to_seconds('../transcript/relevant_segments.json')
# Out:
# [{'text': " Worst thing you'd want to do is put on a flat spare, then you'll remove the tire.", 'start_time': '00:00:23', 'end_time': '00:00:27', 'score': 0.48296600580215454}, {'text': ' what holds your tire on.', 'start_time': '00:03:05', 'end_time': '00:03:07', 'score': 0.47747358679771423}, {'text': ' Once the tire is centered, lug nuts are hand tight, take the lug wrench.', 'start_time': '00:04:00', 'end_time': '00:04:05', 'score': 0.4715319573879242}, {'text': ' Grab the spare tire, put it in position.', 'start_time': '00:03:26', 'end_time': '00:03:30', 'score': 0.4660034477710724}, {'text': ' Lift up this cover to access the spare tire.', 'start_time': '00:00:12', 'end_time': '00:00:17', 'score': 0.4637228846549988}, {'text': " You're going to center the spare tire on the wheel studs.", 'start_time': '00:03:30', 'end_time': '00:03:33', 'score': 0.4243428111076355}, {'text': ' flat tire.', 'start_time': '00:00:07', 'end_time': '00:00:08', 'score': 0.4229423999786377}, {'text': " We'll remove the flat tire, set it over here out of the way.", 'start_time': '00:03:16', 'end_time': '00:03:21', 'score': 0.42081761360168457}, {'text': ' Carefully jack the car up.', 'start_time': '00:02:28', 'end_time': '00:02:29', 'score': 0.38971418142318726}, {'text': " Make sure you get the big tire fixed, and we'll get you back on the road as soon as", 'start_time': '00:05:22', 'end_time': '00:05:25', 'score': 0.3862466812133789}, {'text': " Now that the tire is on the ground, we'll go ahead and give them that final tight.", 'start_time': '00:04:55', 'end_time': '00:04:59', 'score': 0.3802434206008911}, {'text': ' to lower the vehicle.', 'start_time': '00:04:30', 'end_time': '00:04:32', 'score': 0.3588915467262268}, {'text': " We've also chucked the wheel on the opposite side of the flat tire, so we're ready to start", 'start_time': '00:00:34', 'end_time': '00:00:39', 'score': 0.35622429847717285}, {'text': " Okay, well we have our spare tire on, it's aired up, we're ready to go.", 'start_time': '00:05:10', 'end_time': '00:05:17', 'score': 0.34949806332588196}, {'text': ' A couple things to remember though is you want to put everything back in the trunk,', 'start_time': '00:05:17', 'end_time': '00:05:19', 'score': 0.33432167768478394}, {'text': ' Remember, we already pre-loosened them when the car was on the ground, making it easy.', 'start_time': '00:02:47', 'end_time': '00:02:50', 'score': 0.3209787607192993}, {'text': " Your owner's manual is a good place to find where to properly jack the vehicle.", 'start_time': '00:01:59', 'end_time': '00:02:05', 'score': 0.3104967772960663}, {'text': " Using it as leverage, it'll help make the car go up easier.", 'start_time': '00:02:19', 'end_time': '00:02:21', 'score': 0.3084530830383301}, {'text': ' Loosen the lug nuts, position yourself firmly, pressing counterclockwise, loosen the lug', 'start_time': '00:01:16', 'end_time': '00:01:23', 'score': 0.29807084798812866}, {'text': ' Well, we have our spare tire in our jack.', 'start_time': '00:00:29', 'end_time': '00:00:32', 'score': 0.29699158668518066}, {'text': ' Then install your lug nuts.', 'start_time': '00:03:43', 'end_time': '00:03:46', 'score': 0.29535481333732605}, {'text': " Again, turning it clockwise, tighten the lugs until they're firm.", 'start_time': '00:04:05', 'end_time': '00:04:11', 'score': 0.27800577878952026}, {'text': ' Trying to do that while the car was jacked up would be very difficult.', 'start_time': '00:02:53', 'end_time': '00:03:00', 'score': 0.2680826485157013}, {'text': " The first thing we'll do is jack the vehicle up.", 'start_time': '00:00:40', 'end_time': '00:00:43', 'score': 0.2675926089286804}, {'text': ' The screw moves in and out, allowing the mechanism to move up and down and lift your car.', 'start_time': '00:01:39', 'end_time': '00:01:44', 'score': 0.2637650966644287}, {'text': ' A little star pattern, making sure we have equal torque on the wheel studs.', 'start_time': '00:05:05', 'end_time': '00:05:10', 's ...
# [(23, 4),
#  (185, 2),
#  (240, 5),
#  (206, 4),
#  (12, 5),
#  (210, 3),
#  (7, 1),
#  (196, 5),
#  (148, 1),
#  (322, 3),
#  (295, 4),
#  (270, 2),
#  (34, 5),
#  (310, 7),
#  (317, 2),
#  (167, 3),
#  (119, 6),
#  (139, 2),
#  (76, 7),
#  (29, 3),
#  (223, 3),
#  (245, 6),
#  (173, 7),
#  (40, 3),
#  (99, 5),
#  (305, 5),
#  (319, 3),
#  (46, 7),
#  (204, 2),
#  (107, 5),
#  (251, 3),
#  (164, 3),
#  (133, 2),
#  (56, 3),
#  (70, 6),
#  (94, 1),
#  (276, 4),
#  (149, 4),
#  (142, 6),
#  (182, 3),
#  (180, 2),
#  (187, 9),
#  (282, 3),
#  (104, 3),
#  (266, 4),
#  (201, 3),
#  (135, 4),
#  (213, 1),
#  (272, 4),
#  (64, 6),
#  (53, 3),
#  (226, 5),
#  (84, 2),
#  (231, 9),
#  (220, 3),
#  (39, 1),
#  (22, 1),
#  (285, 5),
#  (153, 4),
#  (290, 3),
#  (59, 5),
#  (214, 6),
#  (116, 3),
#  (125, 8),
#  (293, 2),
#  (299, 5),
#  (86, 8),
#  (280, 2),
#  (83, 1),
#  (43, 3),
#  (17, 5),
#  (0, 7),
#  (157, 7),
#  (96, 3),
#  (171, 2),
#  (27, 2),
#  (32, 2),
#  (8, 4),
#  (112, 4),
#  (254, 12),
#  (95, 1),
#  (304, 1),
#  (326, 2),
#  (325, 1)]

# %%
def trim_and_reencode(input_file, start_time, duration, output_file):
    command = [
        "ffmpeg",
        "-ss", str(start_time),  # Start time
        "-i", input_file,        # Input file
        "-t", str(duration),     # Duration
        "-c:v", "libx264",       # Re-encode video to H.264
        "-crf", "23",            # Quality factor for x264
        "-preset", "fast",       # Encoding speed/quality tradeoff
        "-c:a", "aac",           # Re-encode audio
        "-b:a", "128k",          # Audio bitrate
        "-keyint_min", "30",     # Minimum keyframe interval
        "-g", "60",              # Maximum keyframe interval (frames)
        "-sc_threshold", "0",    # Disable scene change detection for consistent keyframes
        output_file
    ]
    subprocess.run(command, check=True)


trim_and_reencode("input/example_input.mp4", 30, 10, "output.mp4")
trim_and_reencode("input/example_input.mp4", 40, 10, "output2.mp4")
# Out:
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955481026/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.27.100
#   Duration: 00:03:10.45, start: 0.000000, bitrate: 2515 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 2383 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x7fca3580c000] using SAR=1/1
# [libx264 @ 0x7fca3580c000] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x7fca3580c000] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x7fca3580c000] 264 - core 161 r3030M 8bd6d28 - H.264/MPEG-4 AVC codec - Copyleft 2003-2020 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=60 keyint_min=30 scenecut=0 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'output.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 23.98 fps, 24k tbn, 23.98 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       encoder         : Lavc58.91.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       encoder         : Lavc58.91.100 aac
# frame=  240 fps= 26 q=-1.0 Lsize=    2123kB time=00:00:10.00 bitrate=1738.2kbits/s dup=1 drop=0 speed=1.07x
# video:1958kB audio:157kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.414925%
# [libx264 @ 0x7fca3580c000] frame I:4     Avg QP:14.94  size: 36820
# [libx264 @ 0x7fca3580c000] frame P:75    Avg QP:17.58  size: 14609
# [libx264 @ 0x7fca3580c000] frame B:161   Avg QP:20.09  size:  4726
# [libx264 @ 0x7fca3580c000] consecutive B-frames:  9.6%  0.8%  6.2% 83.3%
# [libx264 @ 0x7fca3580c000] mb I  I16..4: 42.5% 53.6%  3.9%
# [libx264 @ 0x7fca3580c000] mb P  I16..4:  8.3% 15.7%  0.3%  P16..4: 18.4%  3.6%  1.4%  0.0%  0.0%    skip:52.2%
# [libx264 @ 0x7fca3580c000] mb B  I16..4:  1.4%  1.4%  0.0%  B16..8: 15.2%  1.3%  0.0%  direct: 7.3%  skip:73.4%  L0:44.5% L1:52.3% BI: 3.3%
# [libx264 @ 0x7fca3580c000] 8x8 transform intra:60.8% inter:80.6%
# [libx264 @ 0x7fca3580c000] coded y,uvDC,uvAC intra: 20.7% 55.6% 10.1% inter: 3.5% 10.3% 0.1%
# [libx264 @ 0x7fca3580c000] i16 v,h,dc,p: 40% 32% 13% 15%
# [libx264 @ 0x7fca3580c000] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 25% 25%  3%  3%  3%  3%  2%  3%
# [libx264 @ 0x7fca3580c000] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 28% 15%  5%  7%  5%  7%  4%  4%
# [libx264 @ 0x7fca3580c000] i8c dc,h,v,p: 44% 26% 18% 12%
# [libx264 @ 0x7fca3580c000] Weighted P-Frames: Y:9.3% UV:8.0%
# [libx264 @ 0x7fca3580c000] ref P L0: 76.2% 23.8%
# [libx264 @ 0x7fca3580c000] ref B L0: 87.4% 12.6%
# [libx264 @ 0x7fca3580c000] ref B L1: 95.1%  4.9%
# [libx264 @ 0x7fca3580c000] kb/s:1601.49
# [aac @ 0x7fca3580d800] Qavg: 160.357
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955481026/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.27.100
#   Duration: 00:03:10.45, start: 0.000000, bitrate: 2515 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 2383 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x7fa9cc80c000] using SAR=1/1
# [libx264 @ 0x7fa9cc80c000] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x7fa9cc80c000] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x7fa9cc80c000] 264 - core 161 r3030M 8bd6d28 - H.264/MPEG-4 AVC codec - Copyleft 2003-2020 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=60 keyint_min=30 scenecut=0 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'output2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 23.98 fps, 24k tbn, 23.98 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       encoder         : Lavc58.91.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       encoder         : Lavc58.91.100 aac
# frame=  240 fps= 21 q=-1.0 Lsize=    2697kB time=00:00:10.00 bitrate=2207.7kbits/s dup=1 drop=0 speed=0.888x
# video:2531kB audio:157kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.329020%
# [libx264 @ 0x7fa9cc80c000] frame I:4     Avg QP:15.72  size: 61133
# [libx264 @ 0x7fa9cc80c000] frame P:74    Avg QP:18.55  size: 17009
# [libx264 @ 0x7fa9cc80c000] frame B:162   Avg QP:20.65  size:  6715
# [libx264 @ 0x7fa9cc80c000] consecutive B-frames:  7.5%  4.2% 10.0% 78.3%
# [libx264 @ 0x7fa9cc80c000] mb I  I16..4: 39.0% 54.4%  6.6%
# [libx264 @ 0x7fa9cc80c000] mb P  I16..4:  8.5% 15.7%  0.6%  P16..4: 22.2%  4.4%  1.8%  0.0%  0.0%    skip:46.9%
# [libx264 @ 0x7fa9cc80c000] mb B  I16..4:  2.8%  3.2%  0.0%  B16..8: 19.4%  2.2%  0.1%  direct: 7.8%  skip:64.5%  L0:54.1% L1:42.6% BI: 3.4%
# [libx264 @ 0x7fa9cc80c000] 8x8 transform intra:59.0% inter:80.5%
# [libx264 @ 0x7fa9cc80c000] coded y,uvDC,uvAC intra: 26.8% 49.4% 8.0% inter: 4.3% 10.8% 0.1%
# [libx264 @ 0x7fa9cc80c000] i16 v,h,dc,p: 42% 30% 12% 16%
# [libx264 @ 0x7fa9cc80c000] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 23% 22%  3%  3%  4%  3%  3%  3%
# [libx264 @ 0x7fa9cc80c000] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 26% 14%  4%  7%  7%  6%  4%  3%
# [libx264 @ 0x7fa9cc80c000] i8c dc,h,v,p: 44% 25% 22%  9%
# [libx264 @ 0x7fa9cc80c000] Weighted P-Frames: Y:5.4% UV:4.1%
# [libx264 @ 0x7fa9cc80c000] ref P L0: 76.3% 23.7%
# [libx264 @ 0x7fa9cc80c000] ref B L0: 87.1% 12.9%
# [libx264 @ 0x7fa9cc80c000] ref B L1: 95.7%  4.3%
# [libx264 @ 0x7fa9cc80c000] kb/s:2070.76
# [aac @ 0x7fa9cc80d800] Qavg: 166.651
